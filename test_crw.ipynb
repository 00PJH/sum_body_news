# %%
import pymysql
import pandas as pd

# %%
# MySQL 연결
db = pymysql.connect(
    host="localhost",
    user="root",
    password="1514",
    database="news_db_one_page",
    charset="utf8mb4")

# %%
# title 개수
sql = '''
SELECT title,time,body
FROM news

'''

# %%
# Connection 객체로부터 cursor() 메서드를 호출하여 Cursor 객체를 가져옴
cursor = db.cursor(pymysql.cursors.DictCursor)

# 실행하기
cursor.execute(sql)

# 모든 데이터를 가져온다.
datas = cursor.fetchall() 

# 사용했던 데이터베이스 관련 자원들을 닫아준다.
cursor.close()
db.close()

# 결과를 pandas 데이터프레임으로 변환
df = pd.DataFrame(datas)

# df = df.sort_values("time", ascending = False)


df.to_csv('./news_titles_body_one_page.csv', index = False)

# %%
df = df.sort_values("time", ascending = False)
df
# Out:
#                                                 title newsroom  \
# 3                  LIG넥스원 vs 한화시스템…'정찰용 무인수상정' 입찰 갈등       뉴시스
# 2                            <기고>영국 핵 잠수함이 부두에 묶인 이유      한국일보
# 6                    몸집 키우는 한화에어로, '방산·우주' 전방위 인재 사냥       블로터
# 5         김용현 국방장관 후보, 9월2일 청문회…野 "수사외압" vs 金 "정치선동"     머니투데이
# 0                     '1조 클럽' 앞둔 K방산 "라인 풀가동해 적기 납품"      서울경제
# 14                      한화에어로, 美법인장에 美해군-록히드마틴 출신 선임      동아일보
# 4                   LIG넥스원, 해군 무인수상정 '우선협상대상자' 선정 유력      한국경제
# 12                      창원특례시, “드론 제조 국산화 도시 선점 나선다”     아시아경제
# 9                           수출용 미사일 사거리 300→500㎞로 확대      한국경제
# 8                  세계 제패할 기세… K-방산, 수출 200억 달러 ‘청신호’      국민일보
# 15              軍 아파치 36대 추가 도입…美 4.7조원 제시 치열한 협상 예고     헤럴드경제
# 10   오는 22일 ‘무기체계 제안서 작성 및 평가방식의 문제와 해법’ 주제로 국회에서 개최     뉴스투데이
# 11  제6회 대한민국방위산업전(DX KOREA 2024), 준비 본격화...‘평화와 미래...     뉴스로드
# 13                    하이브리드 전쟁 대비 첫 ‘민·관·군 사이버 통합훈련’      국방일보
# 7                                   북한군 추정 1명 MDL 넘어      국방일보
# 1                      “강력한 국방력 건설, 튼튼한 중소 방산기업이 기초”      국방일보
#
#                     time                                               body
# 3    2024.08.21. 오후 7:55  ​​​​​방위사업청이 공고한 '정찰용 무인수상정'(USV) 사업에서 LIG넥스원이 ...
# 2    2024.08.21. 오후 7:01  ​​​잠수함은 경영학적 관점에서 볼 때, 유지가 매우 어려운 시장이다. 다른 산업군...
# 6    2024.08.21. 오후 5:47  ​​한화에어로스페이스가 우주·방산전문가 영입에 박차를 가하고 있다. 우주산업은 연구...
# 5    2024.08.21. 오후 5:20  ​​​국회 국방위원회 소속 여야 의원들이 다음달 2일 김용현 국방부 장관 후보자에 ...
# 0    2024.08.21. 오후 5:19  ​​​최근 해외에서 잇달아 수주 낭보를 전하고 있는 국내 방산 기업들이 생산 라인을...
# 14   2024.08.21. 오전 3:03  ​​​한화에어로스페이스가 미국 법인인 한화디펜스USA 법인장을 교체했다. 신임 법인...
# 4    2024.08.20. 오후 9:03  ​​​우리 군의 '정찰용 무인수상정(USV)' 사업에서 LIG넥스원이 우선협상대상자...
# 12   2024.08.20. 오후 1:38  ​​​경남 창원특례시가 드론(초경량비행장치) 제조 국산화 도시 선점에 나선다.현재 ...
# 9    2024.08.20. 오전 2:10  ​​​정부가 수출용 미사일의 사정거리 제한을 기존 300㎞에서 500㎞로 확대·허용...
# 8   2024.08.20. 오전 12:04  ​​​글로벌 방산 시장에서 ‘K-방산’의 위상이 높아지고 있다. 국내 방산업계는 중...
# 15  2024.08.20. 오전 10:10  ​​​군이 현존 최강의 공격헬기로 평가받는 아파치(AH-64E) 36대 추가 도입을...
# 10      2024.08.19 13:35  ​​​뉴스투데이(발행인 강남욱 대표)가 오는 22일 한국안보협업연구소(이사장 최차규...
# 11      2024.08.19 10:51  ​​​세계 7위 규모의 국제 방산전시회 ‘제6회 대한민국방위산업전(DX KOREA ...
# 13  2024. 08. 21   16:59  ★2024년 8월22일 목요일 방산뉴스 브리핑★​​국가안보실은 21일 ‘을지 자유의...
# 7   2024. 08. 20   17:00  ★2024년 8월21일 수요일 방산뉴스 브리핑★​​북한군으로 추정되는 1명이 20일...
# 1   2024. 08. 19   17:36  ★2024년 8월20일 화요일 방산뉴스 브리핑★​​‘대한민국의 미래 성장동력’ K방...
